# %% [markdown]
# visitar imdb por género, género comedia
#
# visitar las 15 primeras páginas y obtener las 50 películas de cada página
# durante esa visita visitar cada una de las películas para obtener la siguiente información
#
# - a) el puesto
# - b) el título
# - c) el director
# - d) los actores
# - e) el número de reseñas de usuarios y de críticos
#
# Hay que considerar que algunas informaciones igual no se obtienen.

# %%
# !cd
# Out:
# c:\Users\Aitor\Desktop\IMDBapp\notebooks

# %%
# !scrapy startproject proyecto_imdb ../IMDBapp
# Out:
# New Scrapy project 'proyecto_imdb', using template directory 'C:\Users\Aitor\Desktop\IMDBapp\Lib\site-packages\scrapy\templates\project', created in:
#     c:\Users\Aitor\Desktop\IMDBapp\IMDBapp
#
# You can start your first spider with:
#     cd ../IMDBapp
#     scrapy genspider example example.com

# %%
# !cd ../IMDBapp/proyecto_imdb && scrapy genspider imdb https://www.imdb.com
# Out:
# Created spider 'imdb' using template 'basic' in module:
#   proyecto_imdb.spiders.imdb

# %%
# !cd ../IMDBapp/proyecto_imdb/spiders && scrapy crawl imdb
# Out:
# 1. - Miércoles - https://www.imdb.com//title/tt13443470/ -
# 2. - The White Lotus - https://www.imdb.com//title/tt13406094/ -
# 3. - El espíritu de la Navidad - https://www.imdb.com//title/tt10999120/ -
# 4. - El menú - https://www.imdb.com//title/tt9764362/ -
# 5. - Desencantada: Vuelve Giselle - https://www.imdb.com//title/tt1596342/ -
# 6. - Dead to Me - https://www.imdb.com//title/tt8064302/ -
# 7. - Una nueva historia de Navidad - https://www.imdb.com//title/tt17220704/ -
# 8. - El país de los sueños - https://www.imdb.com//title/tt13320662/ -
# 9. - Historias de Navidad - https://www.imdb.com//title/tt0085334/ -
# 10. - Puñales por la espalda. El misterio de Glass Onion - https://www.imdb.com//title/tt11564570/ -
# 11. - Encantada: La historia de Giselle - https://www.imdb.com//title/tt0461770/ -
# 12. - Three Wise Men and a Baby - https://www.imdb.com//title/tt22247482/ -
# 13. - ¡Vaya familia Claus! - https://www.imdb.com//title/tt17047510/ -
# ...
